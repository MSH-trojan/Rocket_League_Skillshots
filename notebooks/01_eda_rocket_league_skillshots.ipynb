# %%
import pandas as pd

# %%
x = pd.read_csv("C:\\Github\\Repositories\\Projects\\Rocket_League_Skillshots\\data\\rocket_league_skillshots.data" , sep = "\s+")
x
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\moham\AppData\Local\Temp\ipykernel_26436\3412918970.py:1: SyntaxWarning: invalid escape sequence '\s'
#   x = pd.read_csv("C:\\Github\\Repositories\\Projects\\Rocket_League_Skillshots\\data\\rocket_league_skillshots.data" , sep = "\s+")
#       BallAcceleration      Time  DistanceWall  DistanceCeil  DistanceBall  \
# 0             6.000000       NaN           NaN           NaN           NaN
# 1          1636.798772  0.000000       3498.01       2012.98    299.668270
# 2          3198.029397  0.138893       3494.08       2012.98    229.896780
# 3             0.000000  0.173617       3494.08       2012.98    237.350599
# 4          9914.766242  0.312510       3500.08       2012.98    151.880921
# ...                ...       ...           ...           ...           ...
# 7185          0.000000  2.057068       3038.61       1945.02   2717.014581
# ...

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7190 entries, 0 to 7189
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   BallAcceleration  7190 non-null   float64
#  1   Time              6892 non-null   float64
#  2   DistanceWall      6892 non-null   float64
#  3   DistanceCeil      6892 non-null   float64
#  4   DistanceBall      6892 non-null   float64
#  5   PlayerSpeed       6892 non-null   float64
#  6   BallSpeed         6892 non-null   float64
#  7   up                6892 non-null   float64
#  8   accelerate        6892 non-null   float64
#  9   slow              6892 non-null   float64
#  10  goal              6892 non-null   float64
#  11  left              6892 non-null   float64
#  12  boost             6892 non-null   float64
#  13  camera            6892 non-null   float64
#  14  down              6892 non-null   float64
#  15  right             6892 non-null   float64
# ...
